# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
get_ipython().run_line_magic('matplotlib','inline')
plt.style.use('seaborn-whitegrid')

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\Heart_Disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df1=df[['trestbps','chol']]
df1.head()
# Out:
#    trestbps  chol
# 0       145   233
# 1       130   250
# 2       130   204
# 3       120   236
# 4       120   354

# %%
x=df1['trestbps']
y=df1['chol']

# %%
sns.lineplot(x,y,dashes=True)
plt.show()

# %%
from scipy.stats import norm
correlation=df1.corr()
print(correlation)
# Out:
#           trestbps      chol
# trestbps  1.000000  0.123174
# chol      0.123174  1.000000

# %%
sns.heatmap(correlation,cmap='BrBG')
plt.show()

# %%
covar=df1.cov()
print(covar)
# Out:
#             trestbps         chol
# trestbps  307.586453   111.967215
# chol      111.967215  2686.426748

# %%
sns.heatmap(covar)
plt.show()

# %% [markdown]
# # Normalization(z-score)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
Age=np.array(df['age'])
Age
# Out:
# array([63, 37, 41, 56, 57, 57, 56, 44, 52, 57, 54, 48, 49, 64, 58, 50, 58,
#        66, 43, 69, 59, 44, 42, 61, 40, 71, 59, 51, 65, 53, 41, 65, 44, 54,
#        51, 46, 54, 54, 65, 65, 51, 48, 45, 53, 39, 52, 44, 47, 53, 53, 51,
#        66, 62, 44, 63, 52, 48, 45, 34, 57, 71, 54, 52, 41, 58, 35, 51, 45,
#        44, 62, 54, 51, 29, 51, 43, 55, 51, 59, 52, 58, 41, 45, 60, 52, 42,
#        67, 68, 46, 54, 58, 48, 57, 52, 54, 45, 53, 62, 52, 43, 53, 42, 59,
#        63, 42, 50, 68, 69, 45, 50, 50, 64, 57, 64, 43, 55, 37, 41, 56, 46,
#        46, 64, 59, 41, 54, 39, 34, 47, 67, 52, 74, 54, 49, 42, 41, 41, 49,
#        60, 62, 57, 64, 51, 43, 42, 67, 76, 70, 44, 60, 44, 42, 66, 71, 64,
#        66, 39, 58, 47, 35, 58, 56, 56, 55, 41, 38, 38, 67, 67, 62, 63, 53,
#        56, 48, 58, 58, 60, 40, 60, 64, 43, 57, 55, 65, 61, 58, 50, 44, 60,
#        54, 50, 41, 51, 58, 54, 60, 60, 59, 46, 67, 62, 65, 44, 60, 58, 68,
# ...

# %%
Age=np.array(df['age'])
print("max age",max(Age))
Age=Age.reshape(303,1)
# Out:
# max age 77

# %%
Age=np.array(df['age'])
print("max age",min(Age))
Age=Age.reshape(303,1)
# Out:
# max age 29

# %%
from scipy import stats
zscore=np.array(stats.zscore(Age))
zscore=zscore[0:302]
zscore=zscore.reshape(2,151)

# %%
zscore
# Out:
# array([[ 0.9521966 , -1.91531289, -1.47415758,  0.18017482,  0.29046364,
#          0.29046364,  0.18017482, -1.1432911 , -0.26098049,  0.29046364,
#         -0.04040284, -0.7021358 , -0.59184697,  1.06248543,  0.40075247,
#         -0.48155814,  0.40075247,  1.28306308, -1.25357993,  1.61392956,
#          0.5110413 , -1.1432911 , -1.36386876,  0.73161895, -1.58444641,
#          1.83450721,  0.5110413 , -0.37126932,  1.17277425, -0.15069166,
#         -1.47415758,  1.17277425, -1.1432911 , -0.04040284, -0.37126932,
#         -0.92271345, -0.04040284, -0.04040284,  1.17277425,  1.17277425,
#         -0.37126932, -0.7021358 , -1.03300228, -0.15069166, -1.69473524,
#         -0.26098049, -1.1432911 , -0.81242462, -0.15069166, -0.15069166,
#         -0.37126932,  1.28306308,  0.84190778, -1.1432911 ,  0.9521966 ,
#         -0.26098049, -0.7021358 , -1.03300228, -2.24617937,  0.29046364,
#          1.83450721, -0.04040284, -0.26098049, -1.47415758,  0.40075247,
# ...

# %% [markdown]
# # Decimal Normalization

# %%
dn=[]
dn.append(Age/pow(10,2) )
dn=np.array(dn)

# %%
dn
# Out:
# array([[[0.63],
#         [0.37],
#         [0.41],
#         [0.56],
#         [0.57],
#         [0.57],
#         [0.56],
#         [0.44],
#         [0.52],
#         [0.57],
#         [0.54],
#         [0.48],
#         [0.49],
#         [0.64],
#         [0.58],
#         [0.5 ],
#         [0.58],
#         [0.66],
#         [0.43],
#         [0.69],
#         [0.59],
#         [0.44],
#         [0.42],
#         [0.61],
#         [0.4 ],
#         [0.71],
#         [0.59],
#         [0.51],
#         [0.65],
#         [0.53],
#         [0.41],
#         [0.65],
#         [0.44],
#         [0.54],
#         [0.51],
#         [0.46],
#         [0.54],
#         [0.54],
#         [0.65],
#         [0.65],
#         [0.51],
#         [0.48],
#         [0.45],
#         [0.53],
#         [0.39],
#         [0.52],
#         [0.44],
#         [0.47],
#         [0.53],
#         [0.53],
#         [0.51],
#         [0.66],
#         [0.62],
#         [0.44],
#         [0.63],
# ...

# %% [markdown]
# # Min-Max Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
Age=np.array(df['age'])
Age=Age.reshape(-1, 1)
MinMax = scaler.fit(Age)

# %%
MinMax
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.transform(Age)
# Out:
# array([[0.70833333],
#        [0.16666667],
#        [0.25      ],
#        [0.5625    ],
#        [0.58333333],
#        [0.58333333],
#        [0.5625    ],
#        [0.3125    ],
#        [0.47916667],
#        [0.58333333],
#        [0.52083333],
#        [0.39583333],
#        [0.41666667],
#        [0.72916667],
#        [0.60416667],
#        [0.4375    ],
#        [0.60416667],
#        [0.77083333],
#        [0.29166667],
#        [0.83333333],
#        [0.625     ],
#        [0.3125    ],
#        [0.27083333],
#        [0.66666667],
#        [0.22916667],
#        [0.875     ],
#        [0.625     ],
#        [0.45833333],
#        [0.75      ],
#        [0.5       ],
#        [0.25      ],
#        [0.75      ],
#        [0.3125    ],
#        [0.52083333],
#        [0.45833333],
#        [0.35416667],
#        [0.52083333],
#        [0.52083333],
#        [0.75      ],
#        [0.75      ],
#        [0.45833333],
#        [0.39583333],
#        [0.33333333],
# ...
